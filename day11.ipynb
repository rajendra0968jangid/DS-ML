# %%
print('hello')
# Out:
# hello

# %% [markdown]
# **Create Dataframe**

# %%
# series -> 1d
from pandas import * # -> not prefer

l = [10,11,12,13,14]
df = Series(l)

print(df)

# question
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
# series -> 1d
from pandas import Series

l = [10,11,12,13]
df = Series(l)

print(df)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
# series -> 1d
import pandas

l = [10,11,12,13,14]
df = pandas.Series(l)

print(df)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
import pandas as pd


l = [10,11,12,13,14]
df = pd.Series(l)

print(df)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
# series -> 1d
import pandas as pd
# 1d -> method series


l = [10,20,30]
df = pd.Series(data=l)
print(df)

df = pd.Series(l)
print(df)

df = pd.Series([10,20,30])
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# 0    10
# 1    20
# 2    30
# dtype: int64
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import numpy as np
import pandas as pd

data = np.arange(10,15) # last number exclude
df = pd.Series(data)
print(df)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
import pandas as pd

d = {"name":"priyansh","age":20,"roll-no":123}
df = pd.Series(data=d,index=["name","age","roll-no"])
print(df)
# Out:
# name       priyansh
# age              20
# roll-no         123
# dtype: object

# %%
# suggestions
# pd.Series() # ctrl + space | shift + tab
# help(pd.Series)
pd.Series??

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['a', 'b', 'c'])
print(ser)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# !pip install pandas -> use to install pandas

# 2d -> DataFrame
import pandas as pd

# note:-All arrays must be of the same length
data = {
    "name":["priyansh","nitin","shailja","shilpi"],
    "roll-no":[123,456,321,876]
}

df  = pd.DataFrame(data)
print(df)
# Out:
#        name  roll-no
# 0  priyansh      123
# 1     nitin      456
# 2   shailja      321
# 3    shilpi      876

# %%
# 2d -> Dataframe

import pandas as pd

# json format
data = {
    "name":["priyansh","nitin","shailja","bulbul"],
    "roll-no":[123,456,789,321]
}
df = pd.DataFrame(data=data)
print(df)

# note:-All arrays must be of the same length
data = {
    "name":["priyansh","nitin","shailja","bulbul"],
    "roll-no":[123,456,789,np.nan]
}
df = pd.DataFrame(data=data)
print(df)

# by the help of df -> nitin | 789
# print(df["name"][1])
# print(df["roll-no"][2])
# Out:
#        name  roll-no
# 0  priyansh      123
# 1     nitin      456
# 2   shailja      789
# 3    bulbul      321
#        name  roll-no
# 0  priyansh    123.0
# 1     nitin    456.0
# 2   shailja    789.0
# 3    bulbul      NaN

# %%
pd.read_csv
pd.read_json
pd.read_excel
pd.read_html
