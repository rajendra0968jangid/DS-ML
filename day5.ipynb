# %%
# python modules & exception handling
# mysql

# %%
# used to install a package | module
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
# math
# import module_name
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
import math as m
print(m.sqrt(64))
# Out:
# 8.0

# %%
from math import sqrt
print(sqrt(81))
# Out:
# 9.0

# %%
from math import *
print(sqrt(25))
print(pow(2,3))
# Out:
# 5.0
# 8.0

# %%
#%pip install --upgrade pandas

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-08-17 14:08:48.342308

# %%
print(dt.date.today())
# Out:
# 2026-08-17

# %%
import config
print(config.USER_NAME)
print(config.PORT)
# Out:
# ROOT
# 3306

# %% [markdown]
# ---

# %%
import importlib
importlib.reload(config)
print(config.add(20,10))
# Out:
# 30

# %%
print(config.sub(20,10))
# Out:
# 10

# %%
# exception handling
a = 10
b = 0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_685/2468571426.py in <cell line: 0>()
#       2 a = 10
#       3 b = 0
# ----> 4 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
  number = 10/0
except:
  print("something went wrong")
# Out:
# something went wrong

# %%
try:
  num = int(input("Enter number:"))
  print("number:",num)
except ValueError:
  print("Please enter valid number")
# Out:
# Enter number:abs
# Please enter valid number
