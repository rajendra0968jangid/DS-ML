# %%
print("hello")

# %% [markdown]
# **Environment Setup**
#
# **Jupyter Notebook & VS Code Setup**

# %% [markdown]
# **1. python output**

# %%
print("hello")
# Out:
# hello

# %%
print('hello')
# Out:
# hello

# %%
print(100)
# Out:
# 100

# %%
print(10.0)
# Out:
# 10.0

# %% [markdown]
# **2 Variables**

# %%
name = "hello"
print(name)
# Out:
# hello

# %%
num1 = 10
print(num1)
# Out:
# 10

# %%
# 256

a = 10
print(a)
print(id(a))

b = 10
print(b)
print(id(b))
# Out:
# 10
# 11645640
# 10
# 11645640

# %%
# this is an exmaple of immutable
b = 100
print(b)
print(id(b))

b = 200
print(b)
print(id(b))
# Out:
# 100
# 11648520
# 200
# 11651720

# %%
# this is an example of mutable
l = [10]
print(l)
print(id(l))

l[0] = 20
print(l)
print(id(l))
# Out:
# [10]
# 137838793286912
# [20]
# 137838793286912

# %% [markdown]
# **3 Comments**

# %%
#  single line

"""
multi line comments
"""

'''
multi line comments
'''
print("comments")
# Out:
# comments

# %% [markdown]
# **4 Data Types (int, float, str, bool)**

# %%
name = "hello"
print(name)
print(type(name))
# Out:
# hello
# <class 'str'>

# %%
isActive = True
print(isActive)
print(type(isActive))
print(id(isActive))

isActive = False
print(isActive)
print(type(isActive))
print(id(isActive))
# Out:
# True
# <class 'bool'>
# 10549600
# False
# <class 'bool'>
# 10549568

# %%
#default consider -> None
_value = None
print(_value)
print(type(_value))
print(id(_value))

_value = "hello"
print(_value)
print(type(_value))
print(id(_value))
# Out:
# None
# <class 'NoneType'>
# 10623968
# hello
# <class 'str'>
# 137838982513168

# %% [markdown]
# **5 Mutable and immutable**
