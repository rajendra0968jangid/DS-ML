# %% [markdown]
# **Loops**
#
# * for
# * while
# * break,continue,pass

# %% [markdown]
# **Functions & Modules**
#
# * Defining Functions (def, Arguments,Return)
# * Lambda Functions [lambda arguments : expression]
# * List Comprehensions [expression for item in iterable]
# * Map (Transform values), Filter (Select values), * Reduce (Combine values)
# * Importing & Using Modules
#
# 1. Lists
#
# * Indexing & Slicing
# * List Methods(append,insert)
#
# 2. Tuples
#
# 3. Dictionaries
#
# * Key-Value Operations
# * Nested Dictionaries
#
# 4. Sets & Set Operations

# %% [markdown]
# **Lists**
#
# * Indexing & Slicing
# * List Methods(append,insert)

# %% [markdown]
# **Dictionaries**
#
# * Key-Value Operations
# * Nested Dictionaries
